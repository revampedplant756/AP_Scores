# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# !pip install Cython

# %%
import shap
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing

data_df = pd.read_csv("Algo_Data_Version_Three_Exnees.csv")
#"Dyslexic", "Homeless", "Foster Care",
#print(data_df.head())
data_df.drop(columns=["Index", "Dyslexic", "Homeless", "Foster Care", "Year", "District", "Male"], inplace = True, axis =1)

X = data_df.drop('All Students',axis= 1)
y = data_df['All Students'].div(100)

#print(X.head())
#print(y.head())

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

model = LinearRegression()

model.fit(X_train,y_train)
predictions = model.predict(X_test)
Accuracy = r2_score(y_test, predictions)

print('mean_squared_error : ', mean_squared_error(y_test, predictions))
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions))
print('accuracy:', Accuracy)

explainer = shap.Explainer(model.predict, X_test)
shap_values = explainer(X_test)
#shap_values = explainer.shap_values(X)
shap.plots.beeswarm(shap_values)
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
# mean_squared_error :  0.04021915602148656
# mean_absolute_error :  0.1572378112356139
# accuracy: 0.16438792180492523
# Exact explainer: 459it [00:13, 17.46it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
import shap
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from sklearn.metrics import r2_score

data_df = pd.read_csv("Algo_Data_Version_Three_Exnees.csv")
data_df.drop(columns=["Index", "Dyslexic", "Homeless", "Foster Care", "Year", "District", "Male"], inplace = True, axis =1)
data_df["All Students"] = data_df["All Students"].div(100)

X = data_df.drop('All Students',axis= 1)
y = data_df['All Students']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

model = svm.SVR(kernel='poly')

model.fit(X_train,y_train)
predictions = model.predict(X_test)
Accuracy = r2_score(y_test, predictions)

print('mean_squared_error : ', mean_squared_error(y_test, predictions))
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions))
print('accuracy:', Accuracy)

explainer = shap.Explainer(model.predict, X_test)
shap_values = explainer(X_test)
#shap_values = explainer.shap_values(X)
shap.plots.beeswarm(shap_values)
# Out:
# mean_squared_error :  0.0436226509396057
# mean_absolute_error :  0.1505322588394752
# accuracy: 0.22614567878769165
# Exact explainer: 459it [29:04,  3.83s/it]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
import shap
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from sklearn.metrics import r2_score

data_df = pd.read_csv("Algo_Data_Version_Three_Exnees.csv")
data_df.drop(columns=["Index", "Dyslexic", "Homeless", "Foster Care", "Year", "District", "Male"], inplace = True, axis =1)
data_df["All Students"] = data_df["All Students"].div(100)

X = data_df.drop('All Students',axis= 1)
y = data_df['All Students']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

model = RandomForestRegressor(n_estimators=50, oob_score = True, random_state=0)

model.fit(X_train,y_train)
predictions = model.predict(X_test)
Accuracy = r2_score(y_test, predictions)

print('mean_squared_error : ', mean_squared_error(y_test, predictions))
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions))
print('accuracy:', Accuracy)


explainer = shap.Explainer(model.predict, X_test)
shap_values = explainer(X_test)
#shap_values = explainer.shap_values(X)
shap.plots.beeswarm(shap_values)
# Out:
# mean_squared_error :  0.03642135542286379
# mean_absolute_error :  0.13778975946059385
# accuracy: 0.3451208611779931
# Exact explainer: 1375it [04:39,  4.74it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
import shap
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from sklearn.metrics import r2_score

data_df = pd.read_csv("Algo_Data_Version_Three_Exnees.csv")
data_df.drop(columns=["Index", "Dyslexic", "Homeless", "Foster Care", "Year", "District", "Male"], inplace = True, axis =1)
data_df["All Students"] = data_df["All Students"].div(100)

X = data_df.drop('All Students',axis= 1)
y = data_df['All Students']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

model = AdaBoostRegressor(random_state = 0, n_estimators = 100)

model.fit(X_train,y_train)
predictions = model.predict(X_test)
Accuracy = r2_score(y_test, predictions)

print('mean_squared_error : ', mean_squared_error(y_test, predictions))
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions))
print('accuracy:', Accuracy)

explainer = shap.Explainer(model.predict, X_test)
shap_values = explainer(X_test)
#shap_values = explainer.shap_values(X)
shap.plots.beeswarm(shap_values)
# Out:
# mean_squared_error :  0.0435628667108426
# mean_absolute_error :  0.16439496022342984
# accuracy: 0.22720623523651262
# Exact explainer: 459it [00:24, 10.54it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
import shap
import xgboost
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from sklearn.metrics import r2_score

data_df = pd.read_csv("Algo_Data_Version_Three_Exnees.csv")
data_df.drop(columns=["Index", "Dyslexic", "Homeless", "Foster Care", "Year", "District", "Male"], inplace = True, axis =1)
data_df["All Students"] = data_df["All Students"].div(100)

X = data_df.drop('All Students',axis= 1)
y = data_df['All Students']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

model = XGBRegressor(n_estimators=25, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
Accuracy = r2_score(y_test, predictions)

explainer = shap.Explainer(model.predict, X_test)
shap_values = explainer(X_test)
#shap_values = explainer.shap_values(X)
shap.plots.beeswarm(shap_values)

print('mean_squared_error : ', mean_squared_error(y_test, predictions))
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions))
print('accuracy:', Accuracy)
# Out:
# Exact explainer: 459it [00:29, 10.20it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# mean_squared_error :  0.035618803761791565
# mean_absolute_error :  0.13991880586886513
# accuracy: 0.36813181652722415
